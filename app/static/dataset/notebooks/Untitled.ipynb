# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"..\rawdata\Fully_Expanded_Mutual_Funds.csv")
df.head()
# Out:
#                                       stock_holdings  \
# 0  [{'stock_name': 'Persistent Systems Ltd.', 'se...
# 1  [{'stock_name': 'HDFC Bank Ltd.', 'sector': 'F...
# 2  [{'stock_name': 'State Bank of India', 'sector...
# 3  [{'stock_name': 'Reliance Industries Ltd.', 's...
# 4  [{'stock_name': 'Sobha Ltd.', 'sector': 'Const...
#
#                                      peer_comparison  \
# 0  [{'fund_name': 'Motilal Oswal Midcap Fund Dire...
# 1  [{'fund_name': 'JM Flexicap Fund Direct Plan G...
# 2                                                 []
# 3  [{'fund_name': 'Bandhan Small Cap Fund Direct ...
# 4  [{'fund_name': 'Bandhan Small Cap Fund Direct ...
#
#                                        fund_managers  \
# 0  [{'name': 'Ajay Khandelwal', 'tenure': 'Oct 20...
# 1  [{'name': 'Rajeev Thakkar', 'tenure': 'May 201...
# 2  [{'name': 'Rohit Shimpi', 'tenure': 'Jun 2024-...
# 3  [{'name': 'Sameer Kate', 'tenure': 'Mar 2025- ...
# 4  [{'name': 'Manish Gunwani', 'tenure': 'Jan 202...
#
#                                csv_fund_name  \
# 0    Motilal Oswal Midcap Fund Direct Growth
# 1  Parag Parikh Flexi Cap Fund Direct Growth
# 2                 SBI PSU Direct Plan Growth
# 3    Quant Small Cap Fund Direct Plan Growth
# 4       Bandhan Small Cap Fund Direct Growth
#
#                                    fund_name category        cap  \
# 0    Motilal Oswal Midcap Fund Direct Growth   Equity    Mid Cap
# 1  Parag Parikh Flexi Cap Fund Direct Growth   Equity  Flexi Cap
# 2                 SBI PSU Direct Plan Growth   Equity   Thematic
# 3    Quant Small Cap Fund Direct Plan Growth   Equity  Small Cap
# 4       Bandhan Small Cap Fund Direct Growth   Equity  Small Cap
#
#      risk_profile      nav min_sip  ...  P/E Ratio P/B Ratio Alpha  Beta  \
# 0  Very High Risk  ₹114.55    ₹500  ...      61.82      8.28  7.26  0.90
# 1  Very High Risk   ₹89.92  ₹1,000  ...      17.67      3.29  6.98  0.62
# 2  Very High Risk   ₹35.11    ₹500  ...      11.22      1.78  0.97  0.97
# 3  Very High Risk  ₹272.46  ₹1,000  ...      24.22      2.36  4.72  0.90
# 4  Very High Risk   ₹49.40    ₹100  ...      17.87      2.34  7.90  0.89
#
#   Sharpe Sortino Expense ratio  \
# 0   1.10    1.39         0.70%
# 1   1.22    1.68         0.63%
# 2   1.09    2.26         0.81%
# 3   0.85    1.26         0.66%
# 4   1.01    1.70         0.38%
#
#                                            Exit load  \
# 0      Exit load of 1%, if redeemed within 365 days.
# 1  For units above 10% of the investment, exit lo...
# 2     Exit load of 0.50% if redeemed within 30 days.
# 3          Exit load of 1% if redeemed within 1 year
# 4        Exit load of 1%, if redeemed within 1 year.
#
#                      Stamp duty  \
# 0  0.005% (from July 1st, 2020)
# 1  0.005% (from July 1st, 2020)
# 2  0.005% (from July 1st, 2020)
# 3  0.005% (from July 1st, 2020)
# 4  0.005% (from July 1st, 2020)
#
#                                      Tax implication
# 0  Returns are taxed at 20%, if you redeem before...
# 1  Returns are taxed at 20%, if you redeem before...
# 2  Returns are taxed at 20%, if you redeem before...
# 3  Returns are taxed at 20%, if you redeem before...
# 4  Returns are taxed at 20%, if you redeem before...
#
# [5 rows x 51 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1488 entries, 0 to 1487
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   stock_holdings             1488 non-null   object
#  1   peer_comparison            1488 non-null   object
#  2   fund_managers              1488 non-null   object
#  3   csv_fund_name              1488 non-null   object
#  4   fund_name                  1488 non-null   object
#  5   category                   1488 non-null   object
#  6   cap                        1484 non-null   object
#  7   risk_profile               1484 non-null   object
#  8   nav                        1488 non-null   object
#  9   min_sip                    1488 non-null   object
#  10  rating                     851 non-null    float64
#  11  aum                        1472 non-null   object
#  12  min_1st_investment         1488 non-null   object
#  13  min_additional_investment  1488 non-null   object
#  14  min_sip.1                  1488 non-null   object
#  15  fund_returns_1y            1291 non-null   object
#  16  fund_returns_3y            1434 non-null   object
#  17  fund_returns_5y            1364 non-null   object
#  18  fund_returns_all           1484 non-null   object
#  19  category_avg_returns_1y    813 non-null    object
#  20  category_avg_returns_3y    975 non-null    object
#  21  category_avg_returns_5y    1254 non-null   object
#  22  category_avg_returns_all   0 non-null      float64
#  23  rank_in_category_1y        1145 non-null   float64
#  24  rank_in_category_3y        1421 non-null   float64
#  25  rank_in_category_5y        1344 non-null   float64
#  26  rank_in_category_all       0 non-null      float64
#  27  equity_debt_cash_etc       1488 non-null   object
#  28  sector_allocation          1488 non-null   object
#  29  fund_amc                   1487 non-null   object
#  30  rank_aum_incorp            1488 non-null   object
#  31  fund_details               1488 non-null   object
#  32  fund_objective             1488 non-null   object
#  33  fund_benchmark             1453 non-null   object
#  34  fund_sid                   1488 non-null   object
#  35  fund_house_launch_date     1485 non-null   object
#  36  fund_house_custodian       1238 non-null   object
#  37  fund_house_registrar_ta    1488 non-null   object
#  38  other_plans_in_same_fund   1488 non-null   object
#  39  Top 5                      1372 non-null   object
#  40  Top 20                     1372 non-null   object
#  41  P/E Ratio                  900 non-null    float64
#  42  P/B Ratio                  901 non-null    float64
#  43  Alpha                      862 non-null    float64
#  44  Beta                       873 non-null    float64
#  45  Sharpe                     911 non-null    float64
#  46  Sortino                    914 non-null    float64
#  47  Expense ratio              1487 non-null   object
#  48  Exit load                  1488 non-null   object
#  49  Stamp duty                 1488 non-null   object
#  50  Tax implication            1389 non-null   object
# dtypes: float64(12), object(39)
# memory usage: 593.0+ KB

# %%
import google.generativeai as genai
import os

genai.configure(api_key=os.getenv("AIzaSyA6wWdC2xZV5e8OpYLJJ03yIy5HPsm3-3I"))

print("Available Models:\n")

for model in genai.list_models():
    print("Name:", model.name)
    print("Supported Methods:", model.supported_generation_methods)
    print("-" * 40)
